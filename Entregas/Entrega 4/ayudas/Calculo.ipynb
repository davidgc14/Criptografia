# %%
# Datos Marina

E = [18, 8]
Q = [6, 4]
a = E[0]

# %%
# Datos de David

E = [5, 16]
Q = [12, 18]
a = E[0]

# %%
# Datos Wuolah

E = [18, 4]
Q = [10, 3]
a = E[0]

# %%
# Inicialización de datos

x0    = [0,0,0,0,1]
x1    = [0,0,0,1,0]
x2    = [0,0,1,0,0] 
x3    = [0,1,0,0,0] 
x4    = [1,0,0,0,0]
x5    = [0,0,1,0,1]
x6    = [0,1,0,1,0]
x7    = [1,0,1,0,0]
x8    = [0,1,1,0,1]
x9    = [1,1,0,1,0]
x10   = [1,0,0,0,1]
x11   = [0,0,1,1,1]
x12   = [0,1,1,1,0]
x13   = [1,1,1,0,0]
x14   = [1,1,1,0,1]
x15   = [1,1,1,1,1]
x16   = [1,1,0,1,1]
x17   = [1,0,0,1,1]
x18   = [0,0,0,1,1]
x19   = [0,0,1,1,0]
x20   = [0,1,1,0,0]
x21   = [1,1,0,0,0]
x22   = [1,0,1,0,1]
x23   = [0,1,1,1,1]
x24   = [1,1,1,1,0]
x25   = [1,1,0,0,1]
x26   = [1,0,1,1,1]
x27   = [0,1,0,1,1]
x28   = [1,0,1,1,0]
x29   = [0,1,0,0,1]
x30   = [1,0,0,1,0]

vectorGrande = [x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24,x25,x26,x27,x28,x29,x30]

# %%
# Declaración de funciones

def buscarVector(vectorAbuscar, vectorGrande):
    for i in range(len(vectorGrande)):
        if vectorGrande[i] == vectorAbuscar:
            return i
    return -50

def suma(indice1, indice2, vectorGrande):
    vector = [0,0,0,0,0]
    if indice1 == -50:
        return indice2
    if indice2 == -50:
        return indice1

    indice1 = indice1 % 31
    indice2 = indice2 % 31

    for i in range(len(vectorGrande[indice1])):
        vector[i] = (vectorGrande[indice1][i] + vectorGrande[indice2][i]) % 2
    return buscarVector(vector, vectorGrande)

def producto(indice1, indice2):
    if indice1 == -50 or indice2 == -50:
        return -50
    n = indice1 + indice2
    n = n % 31
    return n

# %%
# Sección primera. Puntos de la tabla

# Primer punto

print("Punto 1: ", Q)

# Segundo punto

lam2 = suma(Q[0], producto(Q[1], -Q[0]), vectorGrande)
p2 = suma(suma(2*lam2, lam2, vectorGrande), a, vectorGrande)
q2 = suma(producto(lam2, suma(Q[0], p2, vectorGrande)), suma(p2, Q[1], vectorGrande), vectorGrande)

Q2 = [p2, q2]
# print("Lamda: ",lam2)
print("Punto 2: ",Q2)


# Tercer punto

lam3 = producto(suma(Q2[1], Q[1], vectorGrande), -suma(Q2[0], Q[0], vectorGrande))
p3 = suma(suma(suma(2*lam3, lam3, vectorGrande), suma(a, Q2[0], vectorGrande), vectorGrande), Q[0], vectorGrande)
q3 = suma(producto(lam3, suma(Q2[0], p3, vectorGrande)), suma(p3, Q2[1], vectorGrande), vectorGrande)

Q3 = [p3, q3]
# print("Lamda: ",lam3)
print("Punto 3: ", Q3)


# Cuarto punto

lam4 = producto(suma(Q3[1], Q[1], vectorGrande), -suma(Q3[0], Q[0], vectorGrande))
p4 = suma(suma(suma(2*lam4, lam4, vectorGrande), suma(a, Q3[0], vectorGrande), vectorGrande), Q[0], vectorGrande)
q4 = suma(producto(lam4, suma(Q3[0], p4, vectorGrande)), suma(p4, Q3[1], vectorGrande), vectorGrande)

Q4 = [p4, q4]
# print("Lamda: ",lam4)
print("Punto 4: ", Q4)


# Quinto punto

lam5 = producto(suma(Q4[1], Q[1], vectorGrande), -suma(Q4[0], Q[0], vectorGrande))
p5 = suma(suma(suma(2*lam5, lam5, vectorGrande), suma(a, Q4[0], vectorGrande), vectorGrande), Q[0], vectorGrande)
q5 = suma(producto(lam5, suma(Q4[0], p5, vectorGrande)), suma(p5, Q4[1], vectorGrande), vectorGrande)

Q5 = [p5, q5]
# print("Lamda: ",lam5)
print("Punto 5: ", Q5)


# Sexto punto

lam6 = producto(suma(Q5[1], Q[1], vectorGrande), -suma(Q5[0], Q[0], vectorGrande))
p6 = suma(suma(suma(2*lam6, lam6, vectorGrande), suma(a, Q5[0], vectorGrande), vectorGrande), Q[0], vectorGrande)
q6 = suma(producto(lam6, suma(Q5[0], p6, vectorGrande)), suma(p6, Q5[1], vectorGrande), vectorGrande)

Q6 = [p6, q6]
# print("Lamda: ",lam6)
print("Punto 6: ", Q6)
# Out:
# Punto 1:  [10, 3]
# Punto 2:  [17, 5]
# Punto 3:  [3, 1]
# Punto 4:  [6, 7]
# Punto 5:  [26, 2]
# Punto 6:  [18, 6]
# Punto 7:  [5, 26]

# %%
# Séptimo punto

lam7 = producto(suma(Q6[1], Q[1], vectorGrande), -suma(Q6[0], Q[0], vectorGrande))
p7 = suma(suma(suma(2*lam7, lam7, vectorGrande), suma(a, Q6[0], vectorGrande), vectorGrande), Q[0], vectorGrande)
q7 = suma(producto(lam7, suma(Q6[0], p7, vectorGrande)), suma(p7, Q6[1], vectorGrande), vectorGrande)

Q7 = [p7, q7]
print("Lamda: ",lam7)
print("Punto 7: ", Q7)

Q_7 = [Q7[0], suma(Q7[0], Q7[1], vectorGrande)]
print("Punto -7: ", Q_7)
# Out:
# Lamda:  2
# Punto 7:  [5, 26]
# Punto -7:  [5, 30]

# %%
# Sección de inversos

## Segundo punto

lam2_7 = suma(Q_7[0], producto(Q_7[1], -Q_7[0]), vectorGrande)
p2_7 = suma(suma(suma(2*lam2_7, lam2_7, vectorGrande), suma(a, Q_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q2_7 = suma(producto(lam2_7, suma(Q_7[0], p2_7, vectorGrande)), suma(p2_7, Q_7[1], vectorGrande), vectorGrande)

Q2_7 = [p2_7, q2_7]
print("Lamda: ",lam2_7)
print("Punto 2(-7): ", Q2_7)


# Tercer punto

lam3_7 = producto(suma(Q2_7[1], Q7[1], vectorGrande), -suma(Q2_7[0], Q7[0], vectorGrande))
p3_7 = suma(suma(suma(2*lam3_7, lam3_7, vectorGrande), suma(a, Q2_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q3_7 = suma(producto(lam3_7, suma(Q2_7[0], p3_7, vectorGrande)), suma(p3_7, Q2_7[1], vectorGrande), vectorGrande)

Q3_7 = [p3_7, q3_7]
# print("Lamda: ",lam3_7)
print("Punto 3(-7): ", Q3_7)


# Cuarto punto

lam4_7 = producto(suma(Q3_7[1], Q7[1], vectorGrande), -suma(Q3_7[0], Q7[0], vectorGrande))
p4_7 = suma(suma(suma(2*lam4_7, lam4_7, vectorGrande), suma(a, Q3_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q4_7 = suma(producto(lam4_7, suma(Q3_7[0], p4_7, vectorGrande)), suma(p4_7, Q3_7[1], vectorGrande), vectorGrande)

Q4_7 = [p4_7, q4_7]
# print("Lamda: ",lam4_7)
print("Punto 4(-7): ", Q4_7)


# Quinto punto

lam5_7 = producto(suma(Q4_7[1], Q7[1], vectorGrande), -suma(Q4_7[0], Q7[0], vectorGrande))
p5_7 = suma(suma(suma(2*lam5_7, lam5_7, vectorGrande), suma(a, Q4_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q5_7 = suma(producto(lam5_7, suma(Q4_7[0], p5_7, vectorGrande)), suma(p5_7, Q4_7[1], vectorGrande), vectorGrande)

Q5_7 = [p5_7, q5_7]
# print("Lamda: ",lam5_7)
print("Punto 5(-7): ", Q5_7)


# Sexto punto

lam6_7 = producto(suma(Q5_7[1], Q7[1], vectorGrande), -suma(Q5_7[0], Q7[0], vectorGrande))
p6_7 = suma(suma(suma(2*lam6_7, lam6_7, vectorGrande), suma(a, Q5_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q6_7 = suma(producto(lam6_7, suma(Q5_7[0], p6_7, vectorGrande)), suma(p6_7, Q5_7[1], vectorGrande), vectorGrande)

Q6_7 = [p6_7, q6_7]
# print("Lamda: ",lam6_7)
print("Punto 6(-7): ", Q6_7)


# Séptimo punto

lam7_7 = producto(suma(Q6_7[1], Q7[1], vectorGrande), -suma(Q6_7[0], Q7[0], vectorGrande))
p7_7 = suma(suma(suma(2*lam7_7, lam7_7, vectorGrande), suma(a, Q6_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q7_7 = suma(producto(lam7_7, suma(Q6_7[0], p7_7, vectorGrande)), suma(p7_7, Q6_7[1], vectorGrande), vectorGrande)

Q7_7 = [p7_7, q7_7]
# print("Lamda: ",lam7_7)
print("Punto 7(-7): ", Q7_7)


# Octavo punto

lam8_7 = producto(suma(Q7_7[1], Q7[1], vectorGrande), -suma(Q7_7[0], Q7[0], vectorGrande))
p8_7 = suma(suma(suma(2*lam8_7, lam8_7, vectorGrande), suma(a, Q7_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q8_7 = suma(producto(lam8_7, suma(Q7_7[0], p8_7, vectorGrande)), suma(p8_7, Q7_7[1], vectorGrande), vectorGrande)

Q8_7 = [p8_7, q8_7]
# print("Lamda: ",lam8_7)
print("Punto 8(-7): ", Q8_7)


# Noveno punto

lam9_7 = producto(suma(Q8_7[1], Q7[1], vectorGrande), -suma(Q8_7[0], Q7[0], vectorGrande))
p9_7 = suma(suma(suma(2*lam9_7, lam9_7, vectorGrande), suma(a, Q8_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q9_7 = suma(producto(lam9_7, suma(Q8_7[0], p9_7, vectorGrande)), suma(p9_7, Q8_7[1], vectorGrande), vectorGrande)

Q9_7 = [p9_7, q9_7]
# print("Lamda: ",lam9_7)
print("Punto 9(-7): ", Q9_7)


# Décimo punto

lam10_7 = producto(suma(Q9_7[1], Q7[1], vectorGrande), -suma(Q9_7[0], Q7[0], vectorGrande))
p10_7 = suma(suma(suma(2*lam10_7, lam10_7, vectorGrande), suma(a, Q9_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q10_7 = suma(producto(lam10_7, suma(Q9_7[0], p10_7, vectorGrande)), suma(p10_7, Q9_7[1], vectorGrande), vectorGrande)

Q10_7 = [p10_7, q10_7]
# print("Lamda: ",lam10_7)
print("Punto 10(-7): ", Q10_7)


# Onceavo punto

lam11_7 = producto(suma(Q10_7[1], Q7[1], vectorGrande), -suma(Q10_7[0], Q7[0], vectorGrande))
p11_7 = suma(suma(suma(2*lam11_7, lam11_7, vectorGrande), suma(a, Q10_7[0], vectorGrande), vectorGrande), Q7[0], vectorGrande)
q11_7 = suma(producto(lam11_7, suma(Q10_7[0], p11_7, vectorGrande)), suma(p11_7, Q10_7[1], vectorGrande), vectorGrande)

Q11_7 = [p11_7, q11_7]
# print("Lamda: ",lam11_7)
print("Punto 11(-7): ", Q11_7)
# Out:
# Lamda:  13
# Punto 2(-7):  [3, 1]
# Punto 3(-7):  [5, 30]
# Punto 4(-7):  [12, 4]
# Punto 5(-7):  [5, 30]
# Punto 6(-7):  [12, 4]
# Punto 7(-7):  [5, 30]
# Punto 8(-7):  [12, 4]
# Punto 9(-7):  [5, 30]
# Punto 10(-7):  [12, 4]
# Punto 11(-7):  [5, 30]
